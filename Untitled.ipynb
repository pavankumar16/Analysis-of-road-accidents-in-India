# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from math import sqrt
import numpy as np
import seaborn as sns

df=pd.read_csv('monthlyaccidents.csv')

#sample=df.height.sample(0-3hrs. (night))

#plt.hist(sample)

# %%
b=df[['YEAR','jan_mar','apr_june','jul_sep','oct_dec']].groupby("YEAR").sum().plot(figsize=(20,7));
b.set_xlabel('Year')
b.set_ylabel('total accidents  ')
b.set_title('total accidents ')
# Out:
# Text(0.5,1,'total accidents ')

# %%
df.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000183ACD6C4A8>,
# ...
#       dtype=object)

# %%
x=[482719,459272,486141,479663,521563,473574,440263,438351,435302,454961,457192,473905]
y=["january","february","march","april","may","june","july","august","september","october","november","december"]
plt.plot(y,x)

# %%
plt.style.use('ggplot')

fig=plt.figure(figsize=(18,28))
ax=plt.subplot(2,1,1)
ax=plt.xticks(rotation=90)
ax=sns.boxplot(x='STATE/UT',y='TOTAL',data=df)
ax=plt.title('total accidents in india')

# %%
    x=[390197,474926,671864,859444,824089,906639,873630,602117]
plt.hist(x)
# Out:
# (array([1., 1., 0., 0., 1., 1., 0., 0., 1., 3.]),
#  array([390197. , 441841.2, 493485.4, 545129.6, 596773.8, 648418. ,
#         700062.2, 751706.4, 803350.6, 854994.8, 906639. ]),
#  <a list of 10 Patch objects>)

# %%
y=[390197,474926,671864,859444,824089,906639,873630,602117]
x=["12_3am","3_6am","6_9am","9_12am","12_3pm","3_6pm","6_9pm","9_12pm"]
fig=plt.figure(figsize=(10,5))
plt.bar(x,y)
plt.xlabel("time")
plt.ylabel("accidents")
# Out:
# Text(0,0.5,'accidents')

# %%
s=["A&N","ANDHRA","D&N","D&D","GOA","KARNATAKA","KERALA","LAKSHADWEEP","M.P","MAHARASHTRA","ORISSA","PUDUCHERRY","TAMIL NADU"]
Y=[2893,546821,1303,643,44931,584761,518161,14,394007,641614,115237,21189,852073]
fig=plt.figure(figsize=(15,5))
plt.bar(s,Y)
plt.title("Accidents in South India")
plt.xlabel("states")
plt.ylabel("accidents")
# Out:
# Text(0,0.5,'accidents')

# %%
x=["ARUNACHAL","ASSAM","BIHAR","CHANDIGARH","CHATTISHGARH","DELHI","GUJARAT","HARYANA","H.P","J&K","JHARKHAND","MAINPUR","MEGAHLAYA","MIZORAM","NAGALAND","PUNJAB","RAJASTAN","SIKKHIM","TRIPURA","U.P","U.K","W.B"]
y=[3389,61718,92648,6411,117817,119274,300325,131921,37105,82820,46201,8130,3863,1116,781,46804,323653,2646,10534,274528,18192,189375]
fig=plt.figure(figsize=(20,5))
plt.bar(x,y)

plt.xlabel("states")
plt.ylabel("accidents")
plt.title("Accidents in North India")
# Out:
# Text(0.5,1,'Accidents in North India')
